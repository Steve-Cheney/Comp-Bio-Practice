# %%
# !pip install git+https://github.com/copasi/basico.git
from basico import *
import basico.biomodels as biomodels

info = biomodels.get_model_info(755)
print (info['name'])
print (info['description'])
# get the model itself
load_biomodel(755) #COPASI can only load one model at a time

allspecies = get_species() # you can see that you don't need to pass in the model again
print(allspecies)
allreactions = get_reactions()
print(allreactions)
allparams = get_reaction_parameters()
print(allparams)

result = run_time_course() #default is one second
result.plot();

result = run_time_course(duration=300)
result.plot();
# Out:
# Collecting git+https://github.com/copasi/basico.git
#   Cloning https://github.com/copasi/basico.git to /tmp/pip-req-build-o9fjr5m0
#   Running command git clone --filter=blob:none --quiet https://github.com/copasi/basico.git /tmp/pip-req-build-o9fjr5m0
#   Resolved https://github.com/copasi/basico.git to commit 2bfe0f092b0229f084df976fad17fd76d17d70f6
#   Preparing metadata (setup.py) ... done
# Collecting python-copasi (from copasi-basico==0.52+3.g2bfe0f0)
#   Downloading python_copasi-4.41.280-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 23.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from copasi-basico==0.52+3.g2bfe0f0) (1.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from copasi-basico==0.52+3.g2bfe0f0) (1.23.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from copasi-basico==0.52+3.g2bfe0f0) (3.7.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from copasi-basico==0.52+3.g2bfe0f0) (6.0.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from copasi-basico==0.52+3.g2bfe0f0) (1.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->copasi-basico==0.52+3.g2bfe0f0) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->copasi-basico==0.52+3.g2bfe0f0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->copasi-basico==0.52+3.g2bfe0f0) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->copasi-basico==0.52+3.g2bfe0f0) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->copasi-basico==0.52+3.g2bfe0f0) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->copasi-basico==0.52+3.g2bfe0f0) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->copasi-basico==0.52+3.g2bfe0f0) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->copasi-basico==0.52+3.g2bfe0f0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->copasi-basico==0.52+3.g2bfe0f0) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->copasi-basico==0.52+3.g2bfe0f0) (1.16.0)
# Building wheels for collected packages: copasi-basico
#   Building wheel for copasi-basico (setup.py) ... done
#   Created wheel for copasi-basico: filename=copasi_basico-0.52+3.g2bfe0f0-py3-none-any.whl size=179043 sha256=5d4c79ce331cd979b82761fdd6df013087046b53429dcedfcee76cfca388c2a3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9gyhguh4/wheels/bc/32/95/599e855807215d4295bba0dec6e5726554c7ff13ec97bd0544
# Successfully built copasi-basico
# Installing collected packages: python-copasi, copasi-basico
# Successfully installed copasi-basico-0.52+3.g2bfe0f0 python-copasi-4.41.280
# Hansen2019 - Nine species reduced model of blood coagulation
# <notes xmlns="http://www.sbml.org/sbml/level2/version4">
#       <body xmlns="http://www.w3.org/1999/xhtml">
#         <pre>its a nine species reduced model of Hockin 2002. Model uses different level of reduction (5,7,9,11) and testing the best alignment with Hockin model results</pre>
#       </body>
#     </notes>
#             compartment       type    unit  initial_concentration  \
# name
# TF          compartment  reactions  mol/ml           1.000000e-09
# X           compartment  reactions  mol/ml           1.600000e-07
# Xa_Va       compartment  reactions  mol/ml           0.000000e+00
# II          compartment  reactions  mol/ml           1.400000e-06
# IIa         compartment  reactions  mol/ml           0.000000e+00
# Xa_Va_II    compartment  reactions  mol/ml           0.000000e+00
# mIIa        compartment  reactions  mol/ml           0.000000e+00
# mIIa_ATIII  compartment  reactions  mol/ml           0.000000e+00
# IIa_ATIII   compartment  reactions  mol/ml           0.000000e+00
#
#             initial_particle_number initial_expression expression  \
# name
# TF                     6.022141e+14
# X                      9.635425e+16
# Xa_Va                  0.000000e+00
# II                     8.430997e+17
# IIa                    0.000000e+00
# Xa_Va_II               0.000000e+00
# mIIa                   0.000000e+00
# mIIa_ATIII             0.000000e+00
# IIa_ATIII              0.000000e+00
#
#             concentration  particle_number          rate  \
# name
# TF           1.000000e-09     6.022141e+14 -1.940272e-14
# X            1.600000e-07     9.635425e+16 -1.940272e-14
# Xa_Va        0.000000e+00     0.000000e+00  1.940272e-14
# II           1.400000e-06     8.430997e+17 -1.063205e-37
# IIa          0.000000e+00     0.000000e+00  1.063205e-37
# Xa_Va_II     0.000000e+00     0.000000e+00  0.000000e+00
# mIIa         0.000000e+00     0.000000e+00  0.000000e+00
# mIIa_ATIII   0.000000e+00     0.000000e+00  0.000000e+00
# IIa_ATIII    0.000000e+00     0.000000e+00  0.000000e+00
#
#             particle_number_rate           key     sbml_id
# name
# TF                 -1.168459e+10  Metabolite_0          TF
# X                  -1.168459e+10  Metabolite_1           X
# Xa_Va               1.168459e+10  Metabolite_2       Xa_Va
# II                 -6.402769e-14  Metabolite_3          II
# IIa                 6.402769e-14  Metabolite_4         IIa
# Xa_Va_II            0.000000e+00  Metabolite_5    Xa_Va_II
# mIIa                0.000000e+00  Metabolite_6        mIIa
# mIIa_ATIII          0.000000e+00  Metabolite_7  mIIa_ATIII
# IIa_ATIII           0.000000e+00  Metabolite_8   IIa_ATIII
#                                  scheme          flux  particle_flux  \
# name
# reaction 1              TF + X -> Xa_Va  1.940272e-14   1.168459e+10
# reaction 2  TF + X + II -> TF + X + IIa  1.063205e-37   6.402769e-14
# reaction 3       Xa_Va + II -> Xa_Va_II  0.000000e+00   0.000000e+00
# reaction 4     Xa_Va_II -> Xa_Va + mIIa  0.000000e+00   0.000000e+00
# reaction 5  Xa_Va + mIIa -> Xa_Va + IIa  0.000000e+00   0.000000e+00
# reaction 6           mIIa -> mIIa_ATIII  0.000000e+00   0.000000e+00
# reaction 7             IIa -> IIa_ATIII  0.000000e+00   0.000000e+00
#
#                               function         key     sbml_id  \
# name
# reaction 1  Mass action (irreversible)  Reaction_0  reaction_1
# reaction 2  Mass action (irreversible)  Reaction_1  reaction_2
# reaction 3  Mass action (irreversible)  Reaction_2  reaction_3
# reaction 4  Mass action (irreversible)  Reaction_3  reaction_4
# reaction 5  Mass action (irreversible)  Reaction_4  reaction_5
# reaction 6  Mass action (irreversible)  Reaction_5  reaction_6
# reaction 7  Mass action (irreversible)  Reaction_6  reaction_7
#
#                                                       mapping
# name
# reaction 1          {'k1': 121.267, 'substrate': ['TF', 'X']}
# reaction 2  {'k1': 4.74645e-16, 'substrate': ['TF', 'X', '...
# reaction 3  {'k1': 2569840000000.0, 'substrate': ['Xa_Va',...
# reaction 4           {'k1': 77540.2, 'substrate': 'Xa_Va_II'}
# reaction 5  {'k1': 69679400000.0, 'substrate': ['Xa_Va', '...
# reaction 6            {'k1': 0.00472749, 'substrate': 'mIIa'}
# reaction 7              {'k1': 0.0201671, 'substrate': 'IIa'}
#                         value    reaction   type mapped_to
# name
# (reaction 1).k1  1.212670e+02  reaction 1  local
# (reaction 2).k1  4.746450e-16  reaction 2  local
# (reaction 3).k1  2.569840e+12  reaction 3  local
# (reaction 4).k1  7.754020e+04  reaction 4  local
# (reaction 5).k1  6.967940e+10  reaction 5  local
# (reaction 6).k1  4.727490e-03  reaction 6  local
# (reaction 7).k1  2.016710e-02  reaction 7  local
